# %%
import os 

os.chdir("../../")

# %%
# !pwd
# Out:
# /home/vanishhhed/Desktop/codics/PythonCodics/ML/RAG

# %%
import numpy as np
import pandas as pd
import torch
from src.dataset.index import FaissIndex


index = FaissIndex()
# Out:
# Created index instance:
#   embedding model: Snowflake/snowflake-arctic-embed-m on cpu
#   embedding size: 768
#   max sequence length: 512
# Found and loaded:
#   index: indexes/index_IVFFlat.ivf
#   metadata: indexes/faiss_metadata.pkl
# __________________________________________________

# %%
results = index.search("girl named Zero", 15)

for res in results:
    print(res)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5039/1310093269.py in <module>
# ----> 1 results = index.search("girl named Zero", 15)
#       2
#       3 for res in results:
#       4     print(res)
#
# ~/Desktop/codics/PythonCodics/ML/RAG/src/dataset/index.py in search(self, query, top_k)
#     165
#     166             results.append({
# --> 167                 "chunk_text": self.metadata[idx]["chunk_text"],
#     168                 "similarity": dist
#     169             })
#
# IndexError: list index out of range
