# %%
import os 

os.chdir("../../")

# %%
# !pwd
# Out:
# /home/vanishhhed/Desktop/codics/PythonCodics/ML/RAG

# %%
from src.dataset.index import FaissIndex


index = FaissIndex()
# Out:
# Created index instance:
#   embedding model: Snowflake/snowflake-arctic-embed-m on cpu
#   embedding size: 768
#   max sequence length: 512
# Found and loaded:
#   index: indexes/index_FlatIP.ivf
#   metadata: indexes/faiss_metadata.pkl
# __________________________________________________

# %%
results = index.search("girl named Zero", 15)

for res in results:
    print(res)
# Out:
# {'chunk_text': 'Title: Women at the stake Plot: "Granddaughters of Witches"? A discussion about the reality of the modern woman. Featuring anthropologist Carla Cristina Garcia and artist MC Tha.', 'similarity': 0.8562943935394287}
# {'chunk_text': 'Title: Another Evening with Fred Astaire Plot: A one-hour live television special starring Fred Astaire.', 'similarity': 0.8514505624771118}
# {'chunk_text': 'Title: Giovanni Falcone Plot: The story of the first ever "anti-mafia judges pool" established in the \'80s at the Palermo Courthouse, in Sicily, in the \'80s, while two mafia families started a 10-year-long war to obtain the complete control of smuggles.', 'similarity': 0.8512879610061646}
# {'chunk_text': 'Title: 3 Misses Plot: Three stories of people in distress that interlock.', 'similarity': 0.8489789962768555}
# {'chunk_text': 'Title: Extraordinary Summer Plot: About life in the Russian city of Saratov in 1919 during the Russian Civil War.', 'similarity': 0.8455526828765869}
# ...
